# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import re
import tensorflow as tf
import tensorflow.python.platform
from tensorflow.python.platform import gfile
import numpy as np
import pandas as pd
import pickle
import src_example.feature_extractor as fe

# %% [markdown]
# # Test feature extraction

# %%
images_dir = 'Capstone_photo/Random/'
list_images = [images_dir+f for f in os.listdir(images_dir) if re.search('jpg|JPG', f)]

# %%
image1 = fe.extract_features(list_images)
# Out:
# Processing Capstone_photo/Random/IMG_9071.JPG...

# %%
image1[0].shape
# Out:
# (2048,)

# %%
image1.shape # This is a list of numpy arrays
# Out:
# (8, 2048)

# %% [markdown]
# # Looking at photos

# %%
list_images
# Out:
# ['Capstone_photo/Random/IMG_9071.JPG',
#  'Capstone_photo/Random/IMG_9072.JPG',
#  'Capstone_photo/Random/IMG_9073.JPG',
#  'Capstone_photo/Random/IMG_9075.JPG',
#  'Capstone_photo/Random/IMG_9076.JPG',
#  'Capstone_photo/Random/IMG_9077.JPG',
#  'Capstone_photo/Random/IMG_9169.JPG',
#  'Capstone_photo/Random/IMG_9170.JPG']

# %%
fig, axes= plt.subplots(4,2, figsize=(14,10))

for ax, image in zip(axes.flatten(),list_images):
    img = mpimg.imread(image)
    imgplot = ax.imshow(img)
fig.tight_layout()
